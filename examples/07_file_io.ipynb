# %%
import cesiumpy

# %%
path = '../cesiumpy/extension/tests/data/jpn.geo.json'
res = cesiumpy.io.read_geojson(path)
type(res)
# Out:
# list

# %%
viewer = cesiumpy.Viewer()
viewer.entities.add(res)
viewer
# Out:
# <script src="https://cesiumjs.org/Cesium/Build/Cesium/Cesium.js"></script>
# <link rel="stylesheet" href="http://cesiumjs.org/Cesium/Build/Cesium/Widgets/widgets.css" type="text/css">
# <div id="container-4359907344" style="width:100%; height:100%;"><div>
# <script type="text/javascript">
#   var widget = new Cesium.Viewer("container-4359907344");
#   widget.entities.add({polygon : {hierarchy : Cesium.Cartesian3.fromDegreesArray([153.958588, 24.295, 153.953308, 24.292774, 153.946625, 24.293331, 153.942749, 24.296944, 153.939697, 24.300831, 153.938873, 24.306942, 153.940247, 24.312496, 153.947754, 24.319443, 153.952759, 24.321384, 153.960236, 24.321663, 153.96579, 24.31361, 153.96579, 24.309441, 153.963013, 24.29833, 153.958588, 24.295])}});
# ...

# %%
viewer = cesiumpy.Viewer()
viewer.entities.add(res, extrudedHeight=1e6, material='aqua')
viewer
# Out:
# <script src="https://cesiumjs.org/Cesium/Build/Cesium/Cesium.js"></script>
# <link rel="stylesheet" href="http://cesiumjs.org/Cesium/Build/Cesium/Widgets/widgets.css" type="text/css">
# <div id="container-4359443728" style="width:100%; height:100%;"><div>
# <script type="text/javascript">
#   var widget = new Cesium.Viewer("container-4359443728");
#   widget.entities.add({polygon : {hierarchy : Cesium.Cartesian3.fromDegreesArray([153.958588, 24.295, 153.953308, 24.292774, 153.946625, 24.293331, 153.942749, 24.296944, 153.939697, 24.300831, 153.938873, 24.306942, 153.940247, 24.312496, 153.947754, 24.319443, 153.952759, 24.321384, 153.960236, 24.321663, 153.96579, 24.31361, 153.96579, 24.309441, 153.963013, 24.29833, 153.958588, 24.295]), extrudedHeight : 1000000.0, material : Cesium.Color.AQUA}});
# ...

# %%
path = '../cesiumpy/extension/tests/data/coastl_jpn.shp'
res = cesiumpy.io.read_shape(path)
type(res)
# Out:
# list

# %%
viewer = cesiumpy.Viewer()
viewer.entities.add(res, material='red')
viewer
# Out:
# <script src="https://cesiumjs.org/Cesium/Build/Cesium/Cesium.js"></script>
# <link rel="stylesheet" href="http://cesiumjs.org/Cesium/Build/Cesium/Widgets/widgets.css" type="text/css">
# <div id="container-4455474960" style="width:100%; height:100%;"><div>
# <script type="text/javascript">
#   var widget = new Cesium.Viewer("container-4455474960");
# ...
